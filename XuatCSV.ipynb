# %%
import pyodbc
import pandas as pd

# %%
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};'
                      'SERVER=LAPTOP-QUYNH\MSSQLSERVER1;'   
                      'DATABASE=AdventureWorks2022;'
                      'PWD=123456;'
                      'Trusted_Connection=yes;')
df = pd.read_sql_query('SELECT * FROM BikeSales1', conn)
print(df)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#        ProductID  CustomerID  SalesOrderID  OrderQty Class UnitPrice  \
# 0            749       29994         43662         1    H    2146.96
# 1            749       29646         43689         2    H    2146.96
# 2            749       30042         43868         1    H    2146.96
# 3            749       29703         43873         2    H    2146.96
# 4            749       29724         43883         1    H    2146.96
# ...          ...         ...           ...       ...   ...       ...
# 24821        999       29676         71914         1    L     323.99
# 24822        999       30034         71925         4    L     323.99
# 24823        999       29546         71938         4    L     323.99
# ...

# %%
df
# Out:
#        ProductID  CustomerID  SalesOrderID  OrderQty Class UnitPrice  \
# 0            749       29994         43662         1    H    2146.96
# 1            749       29646         43689         2    H    2146.96
# 2            749       30042         43868         1    H    2146.96
# 3            749       29703         43873         2    H    2146.96
# 4            749       29724         43883         1    H    2146.96
# ...          ...         ...           ...       ...   ...       ...
# 24821        999       29676         71914         1    L     323.99
# 24822        999       30034         71925         4    L     323.99
# 24823        999       29546         71938         4    L     323.99
# 24824        999       29873         71941         3    L     323.99
# 24825        999       29715         71948         3    L     323.99
#
#       UnitPriceDiscount  OrderDate                  StoreName          Region  \
# ...

# %%
df.to_csv('BIKE_SALES_CK.csv', index=False)
